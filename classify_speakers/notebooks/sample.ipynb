# %%
import pandas as pd
import numpy as np
from ..feature_selection.optimization import optimize_n_components_plot

# %%
features = pd.read_csv("Credit_card.csv")
labels = pd.read_csv("Credit_card_label.csv")

combined = pd.concat([features, labels], axis=1).dropna()

X = pd.get_dummies(combined[features.columns]).to_numpy()
y = combined[labels.columns].to_numpy()


optimize_n_components_plot(X, 2)
